# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def step_euler(y,h,f):
  next_y=y+h*f(y)
  return next_y

def euler (h,f,y_0,start_t,end_t):
  N= int((end_t - start_t)/h)
  t_list=np.linspace(start_t,end_t,N+1)

  y_list=np.zeros(N+1)

  y_list[0]=y_0

  for i in range(0,N):
    y_list[i+1]=step_euler(y_list[i],h,f)

  return t_list,y_list

# %% [markdown]
# condiciones iniciales

# %%
y_0=10
h=0.01
t_0=0
t_N=10

# %% [markdown]
# # 2.1.1

# %%
def g(x):
  dx=np.sin(x)
  return dx

t_list,y_list=euler(h,g,y_0, t_0,t_N)
plt.plot(t_list,y_list, label='Analytic')

plt.legend()

print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
# Out:
# 1014.5751964871671

# %%
for i in np.arange(-1,3,0.2):
  t_list,y_list=euler(h,g,i, t_0,t_N)
  plt.plot(t_list,y_list, label='Euler')

#plt.plot(t_list, np.power(2,t_list),label='Euler')
#plt.legend()
print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
plt.grid()
plt.axis([0,10,-2,4])
# Out:
# 1020.8584222406895
# (0.0, 10.0, -2.0, 4.0)

# %% [markdown]
# #2.1.3

# %%
def g(x):
  dx2= np.cos(x)
  return dx2

t_list,y_list=euler(h,g,y_0, t_0,t_N)
plt.plot(t_list,y_list, label='Analytic')

plt.legend()

print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
# Out:
# 1016.1458582935335

# %%
for i in np.arange(-1,3,0.2):
  t_list,y_list=euler(h,g,i, t_0,t_N)
  plt.plot(t_list,y_list, label='Euler')

#plt.plot(t_list, np.power(2,t_list),label='Euler')
#plt.legend()
print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
plt.grid()
plt.axis([0,10,-2,4])
# Out:
# 1022.4291426088703
# (0.0, 10.0, -2.0, 4.0)

# %% [markdown]
# # 2.2.1

# %%
def g(x):
  dx= 4*x**2 - 16
  return dx

t_list,y_list=euler(h,g,y_0, t_0,t_N)
plt.plot(t_list,y_list, label='Analytic')

plt.legend()

print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
# Out:
# <ipython-input-34-e3ee5a3bf993>:2: RuntimeWarning: overflow encountered in double_scalars
#   dx= 4*x**2 - 16
# inf

# %%
for i in np.arange(-1,3,0.2):
  t_list,y_list=euler(h,g,i, t_0,t_N)
  plt.plot(t_list,y_list, label='Euler')

#plt.plot(t_list, np.power(2,t_list),label='Euler')
#plt.legend()
print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
plt.grid()
plt.axis([0,10,-2,4])
# Out:
# inf
# <ipython-input-34-e3ee5a3bf993>:2: RuntimeWarning: overflow encountered in double_scalars
#   dx= 4*x**2 - 16
# (0.0, 10.0, -2.0, 4.0)

# %% [markdown]
# # 2.2.3

# %%
def g(x):
  dx=x-x**3
  return dx

t_list,y_list=euler(h,g,y_0, t_0,t_N)
plt.plot(t_list,y_list, label='Analytic')

plt.legend()

print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
# Out:
# 1023.0000000911726

# %%
for i in np.arange(-1,3,0.2):
  t_list,y_list=euler(h,g,i, t_0,t_N)
  plt.plot(t_list,y_list, label='Euler')

#plt.plot(t_list, np.power(2,t_list),label='Euler')
#plt.legend()
print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
plt.grid()
plt.axis([0,10,-2,4])
# Out:
# 1022.9999999992891
# (0.0, 10.0, -2.0, 4.0)

# %% [markdown]
# # 2.2.5

# %%
def g(x):
  dx=1+(1/2) * np.cos(x)
  return dx

t_list,y_list=euler(h,g,y_0, t_0,t_N)
plt.plot(t_list,y_list, label='Analytic')

plt.legend()

print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
# Out:
# 1004.8430379273017

# %%
for i in np.arange(-1,3,0.2):
  t_list,y_list=euler(h,g,i, t_0,t_N)
  plt.plot(t_list,y_list, label='Euler')

#plt.plot(t_list, np.power(2,t_list),label='Euler')
#plt.legend()
print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
plt.grid()
plt.axis([0,10,-2,4])
# Out:
# 1013.3226665531247
# (0.0, 10.0, -2.0, 4.0)

# %% [markdown]
# # 2.3.3

# %%
def g(x):
  a=1
  b=2
  dx=-a*x* np.log(b*x)
  return dx

t_list,y_list=euler(h,g,y_0, t_0,t_N)
plt.plot(t_list,y_list, label='Analytic')

plt.legend()

print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
# Out:
# 1023.4999363046435

# %%
for i in np.arange(-1,3,0.2):
  t_list,y_list=euler(h,g,i, t_0,t_N)
  plt.plot(t_list,y_list, label='Euler')

#plt.plot(t_list, np.power(2,t_list),label='Euler')
#plt.legend()
print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
plt.grid()
plt.axis([0,10,-2,4])
# Out:
# 1023.4999631342629
# <ipython-input-40-89d2068e7975>:4: RuntimeWarning: invalid value encountered in log
#   dx=-a*x* np.log(b*x)
# (0.0, 10.0, -2.0, 4.0)

# %% [markdown]
# # 2.4.1

# %%
def g(x):
  dx=x*(1-x)
  return dx

t_list,y_list=euler(h,g,y_0, t_0,t_N)
plt.plot(t_list,y_list, label='Analytic')

plt.legend()

print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
# Out:
# 1022.9999620517044

# %%
for i in np.arange(-1,3,0.2):
  t_list,y_list=euler(h,g,i, t_0,t_N)
  plt.plot(t_list,y_list, label='Euler')

#plt.plot(t_list, np.power(2,t_list),label='Euler')
#plt.legend()
print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
plt.grid()
plt.axis([0,10,-2,4])
# Out:
# 1022.999972534535
# <ipython-input-42-d2e4389c09c4>:2: RuntimeWarning: overflow encountered in double_scalars
#   dx=x*(1-x)
# (0.0, 10.0, -2.0, 4.0)

# %% [markdown]
# # 2.4.3

# %%
def g(x):
  dx=np.tan(x)
  return dx

t_list,y_list=euler(h,g,y_0, t_0,t_N)
plt.plot(t_list,y_list, label='Analytic')

plt.legend()

print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
# Out:
# 1018.45581693506

# %%
for i in np.arange(-1,3,0.2):
  t_list,y_list=euler(h,g,i, t_0,t_N)
  plt.plot(t_list,y_list, label='Euler')

#plt.plot(t_list, np.power(2,t_list),label='Euler')
#plt.legend()
print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
plt.grid()
plt.axis([0,10,-2,4])
# Out:
# 1013.8515935815026
# (0.0, 10.0, -2.0, 4.0)

# %% [markdown]
# # 2.4.5

# %%
def g(x):
  dx=1 - np.exp(-x**2)
  return dx

t_list,y_list=euler(h,g,y_0, t_0,t_N)
plt.plot(t_list,y_list, label='Analytic')

plt.legend()

print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
# Out:
# 1003.9999999999995

# %%
for i in np.arange(-1,3,0.2):
  t_list,y_list=euler(h,g,i, t_0,t_N)
  plt.plot(t_list,y_list, label='Euler')

#plt.plot(t_list, np.power(2,t_list),label='Euler')
#plt.legend()
print(np.abs(y_list[-1]-np.power(2,t_list[-1])))
plt.grid()
plt.axis([0,10,-2,4])
# Out:
# 1011.2000684792483
# (0.0, 10.0, -2.0, 4.0)

# %% [markdown]
# # **2.8**

# %% [markdown]
# ### 2.8.3
#
#
# Explain the results.

# %% [markdown]
# a) Este numeral se resolvió de forma analítica. Se obtuvo que:
#
# $\boxed{x(1) = e^{-1} =  0.3678}$

# %% [markdown]
# b) Ahora, utilizando el método de Euler:

# %%
from IPython.display import display, Math

def h(x):
  return -x

f = 1 # delta t
y_0 = 1 # condición inicial x(0) = 1
start_t = 0 # tiempo inicial
end_t = 1 # tiempo final x(1)

for n in range(5):
  step = 10**(-n)
  t_list,y_list = euler (h,f,y_0,start_t,end_t) 
  display(Math(f'\Delta t = {step} \\rightarrow \hat x = {x[-1]}')) # interesa conocer x(1), es decir el ultimo elemento del array
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-4d904a98433b> in <module>
#      11 for n in range(5):
#      12   step = 10**(-n)
# ---> 13   t_list,y_list = euler (h,f,y_0,start_t,end_t)
#      14   display(Math(f'\Delta t = {step} \\rightarrow \hat x = {x[-1]}')) # interesa conocer x(1), es decir el ultimo elemento del array
#
# <ipython-input-28-07bcfb1b34bd> in euler(h, f, y_0, start_t, end_t)
#       4
#       5 def euler (h,f,y_0,start_t,end_t):
# ----> 6   N= int((end_t - start_t)/h)
#       7   t_list=np.linspace(start_t,end_t,N+1)
#       8
#
# TypeError: unsupported operand type(s) for /: 'int' and 'function'

# %% [markdown]
# c)

# %%
def func11(x):
  return -x

step = 1 # delta t
x0 = 1 # condición inicial x(0) = 1
ti = 0 # tiempo inicial
tf = 1 # tiempo final x(1)

real_solution = np.exp(-1)
deltas = np.array([])
euler_errors = np.array([])

for n in range(5):
  step = 10**(-n)
  deltas = np.append(deltas,step)
  t,x = euler_method(func11,step,x0,ti,tf)
  euler_errors = np.append(euler_errors,abs(x[-1] - real_solution))

plt.figure(figsize=(16,9))
plt.subplot(121)
plt.plot(deltas,euler_errors)
plt.title("$E$ as a function of $\Delta t$",fontsize=15)
plt.xlabel("$\Delta t$",fontsize=15)
plt.ylabel("E",fontsize=15)

plt.subplot(122)
plt.plot(np.log(deltas),np.log(euler_errors))
plt.title("$\ln (E)$ as a function of $\ln (\Delta t)$",fontsize=15)
plt.xlabel("$\ln \Delta t$",fontsize=15)
plt.ylabel("$\ln (E)$",fontsize=15)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-1a657facb5a0> in <module>
#      14   step = 10**(-n)
#      15   deltas = np.append(deltas,step)
# ---> 16   t,x = euler_method(func11,step,x0,ti,tf)
#      17   euler_errors = np.append(euler_errors,abs(x[-1] - real_solution))
#      18
#
# NameError: name 'euler_method' is not defined
